# %%
# %pylab inline
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style('ticks')
sns.set_context('paper')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_json('1S2H_feats_6sep2022.json.zip')
df = df.loc[df['Type']=='Tree']

figure(figsize=(4,4))

scatter(df['PC 1'], df['PC 2'],c= df['mean_pLDDT'], cmap='rainbow_r',vmin=50,vmax=90)
# for _, row in df.iloc[[20,55,83]].iterrows():
#     text(row['PC 1'], row['PC 2'],'x')

savefig('Mad2_landscape.pdf',bbox_inches='tight')

#join_states most_like_1S2H, 1S2H_000 1S2H_046 1S2H_008
#join_states like_1DUJ, 1S2H_020 1S2H_055 1S2H_083
