# %%
# %pylab inline
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style('ticks')
sns.set_context('paper')

import os, shutil
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
inds=['1st9A','1z5yE','1jfuA','1WP0A','1KNGA','1r26A']

figure(figsize=(18,3))

for i, ind in enumerate(inds):
    subplot(1,6,i+1)
    df = pd.read_json('feature_data/%s_feats.json.zip' % ind)
    df = df.loc[df.Type=='Tree']
    df = df.sort_values('mean_pLDDT')
    #df = df.loc[df.mean_pLDDT>65]
    scatter(df['PC 1'], df['PC 2'], c=df['mean_pLDDT'], cmap='rainbow_r', vmin=50, vmax=90)
    # for _, row in df.iterrows():
    #     if row['mean_pLDDT']>70:
    #         print(os.path.basename(row['pdb']), row['mean_pLDDT'])
    xlabel('PC 1')
    ylabel('PC 2')
#     xticks([])
#     yticks([])
    title(ind[:-1].upper())

tight_layout()
savefig('all_landscapes.pdf',bbox_inches='tight')
