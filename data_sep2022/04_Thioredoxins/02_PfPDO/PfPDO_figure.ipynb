# %%
# %pylab inline

import seaborn as sns
import pandas as pd
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import os
sns.set_context('paper')
sns.set_style('ticks')

df = pd.read_json('PfPDO_feats_31aug2022.json.zip')
df = df.loc[df.Type=='Tree']
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize=(3,3))
scatter(df['rmsd_ref_1A8LA']*10, df['mean_pLDDT'])
xlabel('RMSD (Å) to PDB 1A8L')
ylabel('plDDT')
# for _, row in df.iterrows():
#     if row['mean_pLDDT']>70:
#         text(row['rmsd_ref_1A8LA']*10, row['mean_pLDDT'], os.path.basename(row['pdb']))
        
savefig('PfPDO_rmsd.pdf',bbox_inches='tight')

# %%
figure(figsize=(4,4))

scatter(df['PC 1'], df['PC 2'], c=df['mean_pLDDT'], cmap='rainbow_r', vmin=50, vmax=90)
# for _, row in df.iterrows():
#     if row['mean_pLDDT']>70:
#         text(row['PC 1'], row['PC 2'], os.path.basename(row['pdb']))
xticks([])
yticks([])
xlabel('PC 1 (on contacts)')
ylabel('PC 2 (on contacts)')
savefig('PfPDO_PCA.pdf', bbox_inches='tight')
